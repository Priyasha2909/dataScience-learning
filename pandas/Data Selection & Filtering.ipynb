# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
df['Actor']
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df['Actor'][3]
# Out:
# 'Ranbir Kapoor'

# %%
df[['Actor','IMDb']]
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.0
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
# operations on dataframe is not changing actual dataframe

df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
# accessing any row
df.loc[2]     # returns by label (whichever is there in index...abc/0123/.....)
# Out:
# Actor                   Aamir Khan
# Film                        Dangal
# Year                          2016
# Genre                    Biography
# BoxOffice(INR Crore)          2024
# IMDb                           8.4
# Name: 2, dtype: object

# %%
df.iloc[2]   # returns by position (always takes nos)
# Out:
# Actor                   Aamir Khan
# Film                        Dangal
# Year                          2016
# Genre                    Biography
# BoxOffice(INR Crore)          2024
# IMDb                           8.4
# Name: 2, dtype: object

# %%
# row and column
df.loc[9,'IMDb']
# Out:
# np.float64(5.9)

# %%
df.iloc[9,5]
# Out:
# np.float64(5.9)

# %%
# using slicing
df.loc[0:2,["Actor","Year","Film"]]     # inclusive
# Out:
#             Actor  Year             Film
# 0  Shah Rukh Khan  2023          Pathaan
# 1     Salman Khan  2017  Tiger Zinda Hai
# 2      Aamir Khan  2016           Dangal

# %%
df.iloc[0:2,0:2]      # exclusive
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai

# %%
# at and iat are optimised than loc and iloc since they only access one element

df.at[0,"Actor"]
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0,0]
# Out:
# 'Shah Rukh Khan'

# %%
df[df['IMDb']>6]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
ex=df[df['IMDb']>6]["Genre"]
ex
# Out:
# 0              Action
# 2           Biography
# 4          Historical
# 5            Thriller
# 6       Horror Comedy
# 7              Action
# 8              Comedy
# 10    Romantic Comedy
# 11             Action
# Name: Genre, dtype: object

# %%
# checking diff on loc and iloc on ex
ex.loc[5]
# Out:
# 'Thriller'

# %%
ex.iloc[5]
# Out:
# 'Action'

# %%
df[(df['IMDb']>6) & (df["Year"]>2020)]
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
df.query("Year>2019")
# Out:
#             Actor               Film  Year          Genre  \
# 0  Shah Rukh Khan            Pathaan  2023         Action
# 3   Ranbir Kapoor         Brahmastra  2022        Fantasy
# 9   Kartik Aaryan  Bhool Bhulaiyaa 2  2022  Horror Comedy
#
#    BoxOffice(INR Crore)  IMDb
# 0                  1050   7.2
# 3                   431   5.6
# 9                   266   5.9

# %%
df.query("Year>2019 and IMDb>6")
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2
