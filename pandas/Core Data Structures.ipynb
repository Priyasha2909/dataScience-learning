# %%
import pandas as pd

# %%
s = pd.Series([34,54,64,74,84,94])   # Series in pandas is a 1-D (single column) but labelled
s
# Out:
# 0    34
# 1    54
# 2    64
# 3    74
# 4    84
# 5    94
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([10,20,40,50], index=["Priya","Rishit","Umi","Yashi"])    # Giving names to indices

# %%
s2
# Out:
# Priya     10
# Rishit    20
# Umi       40
# Yashi     50
# dtype: int64

# %%
# Now we can fetch marks indiv
print(s2["Umi"])
print(s2["Rishit"])
# Out:
# 40
# 20

# %%
# Dataframes - 2d - rows and cols just like excel

data = {                                                  # Dataframes using dict
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)
